# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import time
from tensorflow import keras
import PIL.Image as pilimg

# %%
mydir = "0702/"
total = mydir + "meta_total.json"
meta = pd.read_json(total)
file = np.array(meta['filename'])
emo = ["anger", "disgust", "fear", "happy", "sadness", "surprise"]

# %%
def reader():
    i = 0
    j = 0
    k = 550
    l = 550
    v = 50
    imlist = []
    Vimlist = []
    target = []
    Vtarget = []
    ds = 0
    while True:
        try:
            dir1 = mydir + emo[j] + "/" + file[i]
            pix = np.array(pilimg.open(dir1))
        except FileNotFoundError:
            if i - j*k >= l:
                j = j + 1
            else:
                i = i+1
                if i == 3350:
                    break
        else:
            if i - j*k < l-v:
                imlist.append(pix)
                target.append(j)
            else:
                Vimlist.append(pix)
                Vtarget.append(j)
            ds = ds +1
            i = i+1
            if i == 2250:
                i = i + l
                l = 2*l
            elif i == 3350:
                break
    X = np.array(imlist).astype('float32')
    VX = np.array(Vimlist).astype('float32')
    y = np.array(target).astype('uint8')
    Vy = np.array(Vtarget).astype('uint8')
    ts = len(X)
    vs = len(VX)
    X, y = tf.constant(X), tf.constant(y)
    VX, Vy = tf.constant(VX), tf.constant(Vy)
    train = (X, y)
    valid = (VX, Vy)
    trainset = tf.data.Dataset.from_tensor_slices(train)
    validset = tf.data.Dataset.from_tensor_slices(valid)
    return trainset, validset, ds, ts, vs

# %%
train_set, valid_set, dataset_size, train_size, valid_size = reader()

# %%
def resize(image, label):
    resized = tf.image.resize(image, [224, 224])
    return resized, label

# %%
def preprocess(image, label):
    resized = resize(image, label)[0]
    final = keras.applications.mobilenet_v2.preprocess_input(resized)
    return final, label

# %%
def mobilev2(batch_size):
    train_raw = train_set.shuffle(1000).repeat()
    train_v2 = train_raw.map(preprocess).batch(batch_size).prefetch(1)
    valid_v2 = valid_set.map(preprocess).batch(batch_size).prefetch(1)
    return train_v2, valid_v2

# %%
def mobilev3(batch_size):
    train_raw = train_set.shuffle(1000).repeat()
    train_v3 = train_raw.map(resize).batch(batch_size).prefetch(1)
    valid_v3 = valid_set.map(resize).batch(batch_size).prefetch(1)
    return train_v3, valid_v3

# %%
def compiler(model, lr=0, op="dec"):
    if op=="sgd":
        optimizer = keras.optimizers.SGD(learning_rate=lr) if lr!=0 else keras.optimizers.SGD()
    elif op=="nes":
        optimizer = keras.optimizers.SGD(learning_rate=lr, momentum=0.9, nesterov=True) if lr!=0 else keras.optimizers.SGD(momentum=0.9, nesterov=True)
    elif op=="adg":
        optimizer = keras.optimizers.Adagrad(learning_rate=lr) if lr!=0 else keras.optimizers.Adagrad()
    elif op=="rms":
        optimizer = keras.optimizers.RMSprop(learning_rate=lr) if lr!=0 else keras.optimizers.RMSprop()
    elif op=="adm":
        optimizer = keras.optimizers.Adam(learning_rate=lr) if lr!=0 else keras.optimizers.Adam()
    else:
        optimizer = keras.optimizers.SGD(learning_rate=0.2, momentum=0.9, decay=0.01)
    model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])
    return model

# %%
def trainer(model, batch_size, trainset, validset):
    history = model.fit(trainset, steps_per_epoch= int(train_size / batch_size), validation_data=validset, validation_steps=int(valid_size / batch_size), epochs=5)
    return model, history

# %%
def tflearn(V, batch_size):
    def basemodel(V):
        if V==2:
            return keras.applications.MobileNetV2(input_shape=(224,224, 3), weights="imagenet", include_top=False)
        elif V==3:
            return keras.applications.MobileNetV3Small(input_shape=(224, 224, 3), weights="imagenet", include_top=False)
    base_model = basemodel(V)
    def tfmodel(V):
        avg = keras.layers.GlobalAveragePooling2D()(base_model.output)
        output = keras.layers.Dense(6, activation="softmax")(avg)
        return keras.models.Model(inputs=base_model.input, outputs=output)
    model = tfmodel(V)
    def dataset(V):
        if V == 2:
            return mobilev2(batch_size)
        elif V == 3:
            return mobilev3(batch_size)
    train, valid = dataset(V)
    return base_model, model, train, valid

# %%
batch_size = 32
base_model, model, trainset, validset = tflearn(3, 32)
# Out:
# Extension horovod.torch has not been built: /usr/local/lib/python3.8/site-packages/horovod/torch/mpi_lib/_mpi_lib.cpython-38-x86_64-linux-gnu.so not found
# If this is not expected, reinstall Horovod with HOROVOD_WITH_PYTORCH=1 to debug the build error.
# Warning! MPI libs are missing, but python applications are still avaiable.
# [2022-07-11 12:25:51.743 tensorflow-2-6-gpu--ml-g4dn-xlarge-7eba0e151157af0bd8a25c896f03:25 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-07-11 12:25:51.769 tensorflow-2-6-gpu--ml-g4dn-xlarge-7eba0e151157af0bd8a25c896f03:25 INFO profiler_config_parser.py:111] Unable to find config at /opt/ml/input/config/profilerconfig.json. Profiler is disabled.

# %%
for layer in base_model.layers:
        layer.trainable = False
model = compiler(model)
model, history = trainer(model, batch_size, trainset, validset)
# Out:
# Epoch 1/5
# 60/60 [==============================] - 8s 40ms/step - loss: 8.2489 - accuracy: 0.3651 - val_loss: 24.1667 - val_accuracy: 0.2292
# Epoch 2/5
# 60/60 [==============================] - 1s 23ms/step - loss: 7.3808 - accuracy: 0.4484 - val_loss: 19.2534 - val_accuracy: 0.2882
# Epoch 3/5
# 60/60 [==============================] - 1s 23ms/step - loss: 3.4532 - accuracy: 0.5219 - val_loss: 18.9345 - val_accuracy: 0.2708
# Epoch 4/5
# 60/60 [==============================] - 1s 23ms/step - loss: 1.9413 - accuracy: 0.5885 - val_loss: 18.2531 - val_accuracy: 0.2639
# Epoch 5/5
# 60/60 [==============================] - 1s 23ms/step - loss: 1.7788 - accuracy: 0.5901 - val_loss: 18.9483 - val_accuracy: 0.2639

# %%
root_logdir = os.path.join(os.curdir, "my_tb_logs")

def get_run_logdir():
    run_id = time.strftime("run_%Y_%m_%d_%H_%M_%S")
    return os.path.join(root_logdir, run_id)

run_logdir = get_run_logdir()
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10)

# %%
for layer in base_model.layers:
    layer.trainable=True
optimizer = keras.optimizers.Adam(learning_rate=0.01, decay=0.001)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])

# %%
history = model.fit(trainset,  steps_per_epoch= int(train_size / batch_size), validation_data=validset,
                    validation_steps=int(valid_size / batch_size), epochs=100, callbacks=[tensorboard_cb])
# Out:
# /usr/local/lib/python3.8/site-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch
100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0053 - accuracy: 0.9979 - val_loss: 7.8921 - val_accuracy: 0.3403
# Epoch 83/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0111 - accuracy: 0.9948 - val_loss: 7.9251 - val_accuracy: 0.3507
# Epoch 84/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0104 - accuracy: 0.9969 - val_loss: 8.0199 - val_accuracy: 0.3333
# Epoch 85/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 8.5255 - val_accuracy: 0.3264
# Epoch 86/100
# 60/60 [==============================] - 4s 63ms/step - loss: 0.0110 - accuracy: 0.9969 - val_loss: 8.8816 - val_accuracy: 0.3090
# Epoch 87/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0283 - accuracy: 0.9922 - val_loss: 8.5710 - val_accuracy: 0.3438
# Epoch 88/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0430 - accuracy: 0.9870 - val_loss: 10.3335 - val_accuracy: 0.3368
# Epoch 89/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0825 - accuracy: 0.9766 - val_loss: 10.0100 - val_accuracy: 0.3194
# Epoch 90/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0316 - accuracy: 0.9885 - val_loss: 8.3897 - val_accuracy: 0.3333
# Epoch 91/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0822 - accuracy: 0.9792 - val_loss: 10.0868 - val_accuracy: 0.3160
# Epoch 92/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0561 - accuracy: 0.9839 - val_loss: 9.6074 - val_accuracy: 0.3507
# Epoch 93/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0808 - accuracy: 0.9729 - val_loss: 7.7642 - val_accuracy: 0.3299
# Epoch 94/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0872 - accuracy: 0.9693 - val_loss: 8.1457 - val_accuracy: 0.3299
# Epoch 95/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0875 - accuracy: 0.9771 - val_loss: 7.3579 - val_accuracy: 0.3924
# Epoch 96/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0517 - accuracy: 0.9807 - val_loss: 6.3334 - val_accuracy: 0.3472
# Epoch 97/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0570 - accuracy: 0.9849 - val_loss: 5.8528 - val_accuracy: 0.3333
# Epoch 98/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0466 - accuracy: 0.9839 - val_loss: 7.2242 - val_accuracy: 0.3194
# Epoch 99/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0487 - accuracy: 0.9828 - val_loss: 6.6653 - val_accuracy: 0.3646
# Epoch 100/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0259 - accuracy: 0.9911 - val_loss: 6.5017 - val_accuracy: 0.3819

# %%
history = model.fit(trainset,  steps_per_epoch= int(train_size / batch_size), validation_data=validset,
                    validation_steps=int(valid_size / batch_size), epochs=100, callbacks=[tensorboard_cb])
# Out:
# Epoch 1/100
# 60/60 [==============================] - 5s 86ms/step - loss: 0.0188 - accuracy: 0.9943 - val_loss: 6.1557 - val_accuracy: 0.3819
# Epoch 2/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0218 - accuracy: 0.9927 - val_loss: 6.2601 - val_accuracy: 0.3403
# Epoch 3/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0471 - accuracy: 0.9875 - val_loss: 7.1063 - val_accuracy: 0.3472
# Epoch 4/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0428 - accuracy: 0.9818 - val_loss: 7.3693 - val_accuracy: 0.3785
# Epoch 5/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0425 - accuracy: 0.9859 - val_loss: 7.4579 - val_accuracy: 0.3229
# Epoch 6/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0354 - accuracy: 0.9880 - val_loss: 7.0953 - val_accuracy: 0.3646
# Epoch 7/100
# 60/60 [==============================] - 4s 67ms/step - loss: 0.0152 - accuracy: 0.9953 - val_loss: 6.9728 - val_accuracy: 0.3681
# Epoch 8/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0241 - accuracy: 0.9927 - val_loss: 7.7814 - val_accuracy: 0.3889
# Epoch 9/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0199 - accuracy: 0.9922 - val_loss: 7.6682 - val_accuracy: 0.3785
# Epoch 10/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0326 - accuracy: 0.9896 - val_loss: 6.9982 - val_accuracy: 0.3576
# Epoch 11/100
# 60/60 [==============================] - 4s 67ms/step - loss: 0.0202 - accuracy: 0.9932 - val_loss: 7.0955 - val_accuracy: 0.3507
# Epoch 12/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0205 - accuracy: 0.9896 - val_loss: 6.4176 - val_accuracy: 0.3438
# Epoch 13/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0364 - accuracy: 0.9880 - val_loss: 5.9835 - val_accuracy: 0.3472
# Epoch 14/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0307 - accuracy: 0.9906 - val_loss: 6.7623 - val_accuracy: 0.3438
# Epoch 15/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0192 - accuracy: 0.9948 - val_loss: 6.2312 - val_accuracy: 0.3576
# Epoch 16/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0097 - accuracy: 0.9964 - val_loss: 6.5971 - val_accuracy: 0.3542
# Epoch 17/100
# 60/60 [==============================] - 4s 67ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 6.8908 - val_accuracy: 0.3576
# Epoch 18/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 7.0029 - val_accuracy: 0.3576
# Epoch 19/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 7.2168 - val_accuracy: 0.3646
# Epoch 20/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 7.2676 - val_accuracy: 0.3681
# Epoch 21/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 7.5044 - val_accuracy: 0.3785
# Epoch 22/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0018 - accuracy: 0.9990 - val_loss: 7.5232 - val_accuracy: 0.3785
# Epoch 23/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 7.6384 - val_accuracy: 0.3681
# Epoch 24/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 7.7169 - val_accuracy: 0.3715
# Epoch 25/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 7.8304 - val_accuracy: 0.3681
# Epoch 26/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 8.0252 - val_accuracy: 0.3785
# Epoch 27/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 7.8808 - val_accuracy: 0.3715
# Epoch 28/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 7.7061 - val_accuracy: 0.4028
# Epoch 29/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 7.6238 - val_accuracy: 0.3993
# Epoch 30/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 7.9386 - val_accuracy: 0.3993
# Epoch 31/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 7.8803 - val_accuracy: 0.3924
# Epoch 32/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 7.8157 - val_accuracy: 0.3889
# Epoch 33/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 7.7490 - val_accuracy: 0.3924
# Epoch 34/100
# 60/60 [==============================] - 4s 65ms/step - loss: 9.4945e-04 - accuracy: 0.9995 - val_loss: 7.7659 - val_accuracy: 0.3924
# Epoch 35/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0018 - accuracy: 0.9990 - val_loss: 7.8423 - val_accuracy: 0.3854
# Epoch 36/100
# 60/60 [==============================] - 4s 65ms/step - loss: 9.9403e-04 - accuracy: 0.9995 - val_loss: 7.8381 - val_accuracy: 0.3889
# Epoch 37/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 7.9364 - val_accuracy: 0.3819
# Epoch 38/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0017 - accuracy: 0.9990 - val_loss: 7.9499 - val_accuracy: 0.3854
# Epoch 39/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 8.1171 - val_accuracy: 0.3854
# Epoch 40/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 8.1506 - val_accuracy: 0.3854
# Epoch 41/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 8.0373 - val_accuracy: 0.3958
# Epoch 42/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 7.8873 - val_accuracy: 0.3924
# Epoch 43/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 7.9264 - val_accuracy: 0.3924
# Epoch 44/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 7.9907 - val_accuracy: 0.3889
# Epoch 45/100
# 60/60 [==============================] - 4s 64ms/step - loss: 1.8270e-04 - accuracy: 1.0000 - val_loss: 8.0430 - val_accuracy: 0.3854
# Epoch 46/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 8.0933 - val_accuracy: 0.3785
# Epoch 47/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0026 - accuracy: 0.9990 - val_loss: 8.1376 - val_accuracy: 0.3819
# Epoch 48/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0020 - accuracy: 0.9990 - val_loss: 8.1739 - val_accuracy: 0.3924
# Epoch 49/100
# 60/60 [==============================] - 4s 64ms/step - loss: 2.7334e-04 - accuracy: 1.0000 - val_loss: 8.2193 - val_accuracy: 0.3889
# Epoch 50/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0022 - accuracy: 0.9984 - val_loss: 8.2839 - val_accuracy: 0.3854
# Epoch 51/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0024 - accuracy: 0.9995 - val_loss: 8.2306 - val_accuracy: 0.3819
# Epoch 52/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0018 - accuracy: 0.9990 - val_loss: 8.1975 - val_accuracy: 0.3854
# Epoch 53/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0018 - accuracy: 0.9990 - val_loss: 8.2803 - val_accuracy: 0.3889
# Epoch 54/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0010 - accuracy: 0.9995 - val_loss: 8.4012 - val_accuracy: 0.3681
# Epoch 55/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 8.1313 - val_accuracy: 0.3681
# Epoch 56/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 8.1965 - val_accuracy: 0.3750
# Epoch 57/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0473 - accuracy: 0.9865 - val_loss: 9.9191 - val_accuracy: 0.3264
# Epoch 58/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.4676 - accuracy: 0.8760 - val_loss: 5.2980 - val_accuracy: 0.2708
# Epoch 59/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.3820 - accuracy: 0.8906 - val_loss: 6.8931 - val_accuracy: 0.3021
# Epoch 60/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.1570 - accuracy: 0.9448 - val_loss: 6.1842 - val_accuracy: 0.3333
# Epoch 61/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0581 - accuracy: 0.9818 - val_loss: 7.0264 - val_accuracy: 0.3333
# Epoch 62/100
# 60/60 [==============================] - 4s 67ms/step - loss: 0.0476 - accuracy: 0.9828 - val_loss: 6.4833 - val_accuracy: 0.3576
# Epoch 63/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0243 - accuracy: 0.9896 - val_loss: 6.4474 - val_accuracy: 0.3819
# Epoch 64/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0238 - accuracy: 0.9943 - val_loss: 6.4410 - val_accuracy: 0.3785
# Epoch 65/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0213 - accuracy: 0.9922 - val_loss: 7.9303 - val_accuracy: 0.3819
# Epoch 66/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0163 - accuracy: 0.9948 - val_loss: 7.0079 - val_accuracy: 0.3681
# Epoch 67/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0092 - accuracy: 0.9974 - val_loss: 6.9185 - val_accuracy: 0.3785
# Epoch 68/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0103 - accuracy: 0.9979 - val_loss: 6.7626 - val_accuracy: 0.3715
# Epoch 69/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0041 - accuracy: 0.9990 - val_loss: 6.9080 - val_accuracy: 0.3750
# Epoch 70/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 7.2050 - val_accuracy: 0.3785
# Epoch 71/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 7.3284 - val_accuracy: 0.3889
# Epoch 72/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 7.4394 - val_accuracy: 0.3854
# Epoch 73/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0021 - accuracy: 0.9990 - val_loss: 7.6962 - val_accuracy: 0.3681
# Epoch 74/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0012 - accuracy: 0.9995 - val_loss: 7.8069 - val_accuracy: 0.3715
# Epoch 75/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 7.9803 - val_accuracy: 0.3750
# Epoch 76/100
# 60/60 [==============================] - 4s 64ms/step - loss: 7.3859e-04 - accuracy: 0.9995 - val_loss: 8.0117 - val_accuracy: 0.3750
# Epoch 77/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 8.0222 - val_accuracy: 0.3646
# Epoch 78/100
# 60/60 [==============================] - 4s 67ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 8.1091 - val_accuracy: 0.3542
# Epoch 79/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 8.2011 - val_accuracy: 0.3681
# Epoch 80/100
# 60/60 [==============================] - 4s 67ms/step - loss: 0.0025 - accuracy: 0.9984 - val_loss: 8.1670 - val_accuracy: 0.3854
# Epoch 81/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 8.1606 - val_accuracy: 0.3819
# Epoch 82/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0010 - accuracy: 0.9995 - val_loss: 8.2026 - val_accuracy: 0.3785
# Epoch 83/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0188 - accuracy: 0.9927 - val_loss: 8.2158 - val_accuracy: 0.3646
# Epoch 84/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0341 - accuracy: 0.9854 - val_loss: 8.3521 - val_accuracy: 0.3403
# Epoch 85/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0305 - accuracy: 0.9870 - val_loss: 8.7852 - val_accuracy: 0.3785
# Epoch 86/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0540 - accuracy: 0.9849 - val_loss: 8.6017 - val_accuracy: 0.3542
# Epoch 87/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0574 - accuracy: 0.9818 - val_loss: 8.4431 - val_accuracy: 0.3576
# Epoch 88/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0723 - accuracy: 0.9740 - val_loss: 9.5091 - val_accuracy: 0.3576
# Epoch 89/100
# 60/60 [==============================] - 4s 65ms/step - loss: 0.0319 - accuracy: 0.9854 - val_loss: 7.7459 - val_accuracy: 0.3646
# Epoch 90/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0166 - accuracy: 0.9948 - val_loss: 8.2453 - val_accuracy: 0.3403
# Epoch 91/100
# 60/60 [==============================] - 4s 67ms/step - loss: 0.0158 - accuracy: 0.9937 - val_loss: 8.6970 - val_accuracy: 0.3750
# Epoch 92/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0163 - accuracy: 0.9927 - val_loss: 8.3537 - val_accuracy: 0.3854
# Epoch 93/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0088 - accuracy: 0.9964 - val_loss: 8.1067 - val_accuracy: 0.3889
# Epoch 94/100
# 60/60 [==============================] - 4s 66ms/step - loss: 0.0125 - accuracy: 0.9948 - val_loss: 8.5634 - val_accuracy: 0.3542
# Epoch 95/100
# 60/60 [==============================] - 4s 64ms/step - loss: 0.0065 - accuracy: 0.9974 - val_loss: 8.9033 - val_accuracy: 0.3750
# Epoch 96/100
# 60/60 [==============================] - 4s 63ms/step - loss: 0.0174 - accuracy: 0.9948 - val_loss: 8.1858 - val_accuracy: 0.3715
# Epoch 97/100
# 60/60 [==============================] - 4s 63ms/step - loss: 0.0034 - accuracy: 0.9995 - val_loss: 8.3334 - val_accuracy: 0.3542
# Epoch 98/100
# 60/60 [==============================] - 4s 63ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 8.2620 - val_accuracy: 0.3611
# Epoch 99/100
# 60/60 [==============================] - 4s 63ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 8.2757 - val_accuracy: 0.3646
# Epoch 100/100
# 60/60 [==============================] - 4s 63ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 8.0656 - val_accuracy: 0.3507
