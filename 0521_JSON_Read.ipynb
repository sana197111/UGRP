# %%
import os
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd

# %%
mydir = "KEmoDataset/"
fmt = ".json"
train = "train_neutral"
valid = "valid_neutral"
tdf = pd.read_json(mydir + train + fmt)
vdf = pd.read_json(mydir + valid + fmt)

# %%
tdf
# Out:
#                                                 filename gender  age isProf  \
# 0      6e941deb878a4582d63d66e8013e26fdca94a935ade338...      여   40    일반인
# 1      ab318a800df44f03eaf62085a34ee2ea62da2891870d7f...      남   20    전문인
# 2      18b7be47586fa292f18031e3cc12a5b986baed03408c67...      여   30    전문인
# 3      d3d3431ea4fe4da48b4ca28b84a84ca4e08be5f970b297...      여   30    전문인
# 4      ca3a4e6e725cbd4765f642703c442507648cefb3eb9262...      여   20    전문인
# ...                                                  ...    ...  ...    ...
# 59228  6bf4bdca7b2b1aa60648e799ed4f90bf2ab74b1f180844...      남   20    일반인
# 59229  28522d4bff1a866424ad74429df06d12000a422caee47e...      여   30    전문인
# 59230  d68e712e65fdf47cfd5738a2c05bdb49d3e0e4e8d1381b...      여   30    일반인
# 59231  1ac0331132346c7900a8dd6f84638e1f5115be2b8040ac...      여   20    일반인
# 59232  11c19b42e141ebd621a096717a4d8c31c43104f557201d...      여   20    일반인
#
#       faceExp_uploader        bg_uploader  \
# ...

# %%
type(tdf)
# Out:
# pandas.core.frame.DataFrame
