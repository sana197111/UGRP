# %%
import os
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras

# %%
model_1 = keras.applications.mobilenet.MobileNet(weights="imagenet")

# %%
model_2 = keras.applications.mobilenet_v2.MobileNetV2(weights="imagenet")

# %%
model_3 = keras.applications.MobileNetV3Small(input_shape=(224, 224, 3), weights="imagenet", minimalistic=True, include_preprocessing=False)

# %%
model_1.summary()
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
# ...

# %%
model_2.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 112, 112, 32  864         ['input_2[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 112, 112, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 112, 112, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 112, 112, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 112, 112, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
# ...

# %%
model_3.summary()
# Out:
# Model: "MobilenetV3small"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv (Conv2D)                  (None, 112, 112, 16  432         ['input_3[0][0]']
#                                 )
#
#  Conv/BatchNorm (BatchNormaliza  (None, 112, 112, 16  64         ['Conv[0][0]']
#  tion)                          )
#
#  re_lu (ReLU)                   (None, 112, 112, 16  0           ['Conv/BatchNorm[0][0]']
#                                 )
#
#  expanded_conv/depthwise/pad (Z  (None, 113, 113, 16  0          ['re_lu[0][0]']
#  eroPadding2D)                  )
#
#  expanded_conv/depthwise (Depth  (None, 56, 56, 16)  144         ['expanded_conv/depthwise/pad[0][
#  wiseConv2D)                                                     0]']
#
# ...

# %%
model_4 = keras.applications.MobileNetV3Small(input_shape=(224, 224, 3), weights="imagenet", minimalistic=False, include_preprocessing=False)

# %%
model_4.summary()
# Out:
# Model: "MobilenetV3small"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv (Conv2D)                  (None, 112, 112, 16  432         ['input_4[0][0]']
#                                 )
#
#  Conv/BatchNorm (BatchNormaliza  (None, 112, 112, 16  64         ['Conv[0][0]']
#  tion)                          )
#
#  tf.__operators__.add (TFOpLamb  (None, 112, 112, 16  0          ['Conv/BatchNorm[0][0]']
#  da)                            )
#
#  re_lu_24 (ReLU)                (None, 112, 112, 16  0           ['tf.__operators__.add[0][0]']
#                                 )
#
#  tf.math.multiply (TFOpLambda)  (None, 112, 112, 16  0           ['re_lu_24[0][0]']
#                                 )
#
# ...

# %%
model_L = keras.applications.MobileNetV3Large(input_shape=(224, 224, 3), weights="imagenet", include_preprocessing=False)
# Out:
# ...
# 22675456/22661472 [==============================] - 2s 0us/step

# %%
model_L.summary()
# Out:
# Model: "MobilenetV3large"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv (Conv2D)                  (None, 112, 112, 16  432         ['input_5[0][0]']
#                                 )
#
#  Conv/BatchNorm (BatchNormaliza  (None, 112, 112, 16  64         ['Conv[0][0]']
#  tion)                          )
#
#  tf.__operators__.add_28 (TFOpL  (None, 112, 112, 16  0          ['Conv/BatchNorm[0][0]']
#  ambda)                         )
#
#  re_lu_57 (ReLU)                (None, 112, 112, 16  0           ['tf.__operators__.add_28[0][0]']
#                                 )
#
#  tf.math.multiply_28 (TFOpLambd  (None, 112, 112, 16  0          ['re_lu_57[0][0]']
#  a)                             )
#
# ...
